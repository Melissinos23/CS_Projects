# %%
import pandas as pd

# %%
crime = pd.read_csv("../../../data/Crime_Data_From_2020_to_Present.csv")

# %%
crime.head(8)
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
# 5  200100501  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM        30     1
# 6  200100502  01/02/2020 12:00:00 AM  01/02/2020 12:00:00 AM      1315     1
# 7  200100504  01/04/2020 12:00:00 AM  01/04/2020 12:00:00 AM        40     1
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# ...

# %%
crime.dtypes
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age            int64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %%
## turn df into an excel document

crimes = crime.head(5)

crimes.to_excel("crime5.xlsx", sheet_name="crimes", index=False)

# %%
## turn excel doc into df

crimes = pd.read_excel("crime5.xlsx", sheet_name="crimes")
crimes
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# ...

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559619 entries, 0 to 559618
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           559619 non-null  int64
#  1   Date Rptd       559619 non-null  object
#  2   DATE OCC        559619 non-null  object
#  3   TIME OCC        559619 non-null  int64
#  4   AREA            559619 non-null  int64
#  5   AREA NAME       559619 non-null  object
#  6   Rpt Dist No     559619 non-null  int64
#  7   Part 1-2        559619 non-null  int64
#  8   Crm Cd          559619 non-null  int64
#  9   Crm Cd Desc     559619 non-null  object
#  10  Mocodes         482136 non-null  object
#  11  Vict Age        559619 non-null  int64
#  12  Vict Sex        485536 non-null  object
#  13  Vict Descent    485531 non-null  object
#  14  Premis Cd       559614 non-null  float64
#  15  Premis Desc     559362 non-null  object
# ...

# %%
desc = crime["Crm Cd Desc"]
desc.head()
type(crime["Crm Cd Desc"])
crime["Crm Cd Desc"].shape
# Out:
# (559619,)

# %%
area_crime = crime[["AREA NAME", "Crm Cd Desc"]]
area_crime.tail()
# Out:
#           AREA NAME                                        Crm Cd Desc
# 559614  77th Street                  INTIMATE PARTNER - SIMPLE ASSAULT
# 559615    Southwest                                  THEFT OF IDENTITY
# 559616  West Valley                                   VEHICLE - STOLEN
# 559617    Northeast                                   VEHICLE - STOLEN
# 559618     Foothill  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...

# %%
type(crime[["AREA NAME", "Crm Cd Desc"]])
# Out:
# pandas.core.frame.DataFrame

# %%
crime[["AREA NAME", "Crm Cd Desc"]].shape
# Out:
# (559619, 2)

# %%
area_crime.shape
# Out:
# (559619, 2)

# %%
## selecting rows

# %%
before_5 = crime[crime["TIME OCC"] < 500]

# %%
before_5
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# 5       200100501  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM        30
# 7       200100504  01/04/2020 12:00:00 AM  01/04/2020 12:00:00 AM        40
# 8       200100507  01/04/2020 12:00:00 AM  01/04/2020 12:00:00 AM       200
# ...           ...                     ...                     ...       ...
# 559592  221407174  01/29/2022 12:00:00 AM  01/26/2022 12:00:00 AM       450
# 559594  220208677  04/04/2022 12:00:00 AM  04/02/2022 12:00:00 AM         1
# 559598  220118304  08/15/2022 12:00:00 AM  08/14/2022 12:00:00 AM       420
# 559609  221907283  03/21/2022 12:00:00 AM  03/20/2022 12:00:00 AM       100
# 559615  220314584  08/02/2022 12:00:00 AM  08/02/2022 12:00:00 AM        10
#
# ...

# %%
before_5.shape
# Out:
# (77945, 28)

# %%
area_67 = crime[crime["AREA"].isin([6, 7])]

## equivalent to crime[(crime["AREA"] == 6) | (crime["AREA"] ==7)]
## | is the or bar

area_67.tail()
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 559571  220705529  02/07/2022 12:00:00 AM  02/07/2022 12:00:00 AM       810
# 559574  220610849  05/27/2022 12:00:00 AM  05/27/2022 12:00:00 AM      1245
# 559580  220604418  01/10/2022 12:00:00 AM  01/10/2022 12:00:00 AM       900
# 559588  220607836  03/23/2022 12:00:00 AM  03/22/2022 12:00:00 AM      1300
# 559604  220712546  08/05/2022 12:00:00 AM  08/04/2022 12:00:00 AM      1730
#
#         AREA  AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 559571     7   Wilshire          767         1     442
# 559574     6  Hollywood          648         2     624
# 559580     6  Hollywood          678         1     815
# 559588     6  Hollywood          632         1     761
# 559604     7   Wilshire          737         1     331
#
#                                               Crm Cd Desc  ... Status  \
# 559571           SHOPLIFTING - PETTY THEFT ($950 & UNDER)  ...     IC
# ...

# %%
age_no_na = crime[crime["Vict Age"].notna()]

age_no_na.shape
# Out:
# (559619, 28)

# %%
age_crime = crime.loc[(crime["Vict Age"] < 10) & (crime["Vict Age"] > 0), "Crm Cd Desc"]
## age 0 is null
## loc[rows, columns]

age_crime.tail()
# Out:
# 558657          CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT
# 559084                       CHILD NEGLECT (SEE 300 W.I.C.)
# 559164                                      BRANDISH WEAPON
# 559289    CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...
# 559388       ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# Name: Crm Cd Desc, dtype: object

# %%
crime.iloc[9:25, 2:5] = "date, time, area" ##rows 10-25, columns 3-5

crime.iloc[9:25, 2:5] ## wack
# Out:
#             DATE OCC          TIME OCC              AREA
# 9   date, time, area  date, time, area  date, time, area
# 10  date, time, area  date, time, area  date, time, area
# 11  date, time, area  date, time, area  date, time, area
# 12  date, time, area  date, time, area  date, time, area
# 13  date, time, area  date, time, area  date, time, area
# 14  date, time, area  date, time, area  date, time, area
# 15  date, time, area  date, time, area  date, time, area
# 16  date, time, area  date, time, area  date, time, area
# 17  date, time, area  date, time, area  date, time, area
# 18  date, time, area  date, time, area  date, time, area
# 19  date, time, area  date, time, area  date, time, area
# 20  date, time, area  date, time, area  date, time, area
# 21  date, time, area  date, time, area  date, time, area
# 22  date, time, area  date, time, area  date, time, area
# 23  date, time, area  date, time, area  date, time, area
# ...

# %%
import matplotlib.pyplot as plt

# %%
airq = pd.read_csv("air_quality_no2.csv")

# %%
airq.head()
# Out:
#       datetime  station_antwerp  station_paris  station_london  Unnamed: 4  \
# 0  5/7/19 2:00              NaN            NaN            23.0         NaN
# 1  5/7/19 3:00             50.5           25.0            19.0         NaN
# 2  5/7/19 4:00             45.0           27.7            19.0         NaN
# 3  5/7/19 5:00              NaN           50.4            16.0         NaN
# 4  5/7/19 6:00              NaN           61.9             NaN         NaN
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
del airq["Unnamed: 5"]
del airq["Unnamed: 4"]

# %%
airq.head()
# Out:
#       datetime  station_antwerp  station_paris  station_london
# 0  5/7/19 2:00              NaN            NaN            23.0
# 1  5/7/19 3:00             50.5           25.0            19.0
# 2  5/7/19 4:00             45.0           27.7            19.0
# 3  5/7/19 5:00              NaN           50.4            16.0
# 4  5/7/19 6:00              NaN           61.9             NaN

# %%
airq.plot()

# %%
airq["station_paris"].plot()

# %%
airq.plot.scatter(x="station_london", y="station_paris", alpha=0.5)

# %%
[
    method_name
    for method_name in dir(airq.plot)
    if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
airq.plot.box()

# %%
axs = airq.plot.area(figsize=(12, 4), subplots=True)

# %%
fig, axs = plt.subplots(figsize=(12, 4))

airq.plot.area(ax=axs)

axs.set_ylabel("NO$_2$ concentration")

fig.savefig("no2_concentrations.png")

# %%
fig, axs = plt.subplots(figsize=(12, 4))        # Create an empty Matplotlib Figure and Axes
airq.plot.area(ax=axs)                   # Use pandas to put the area plot on the prepared Figure/Axes
axs.set_ylabel("NO$_2$ concentration")          # Do any Matplotlib customization you like
fig.savefig("no2_concentrations.png")           # Save the Figure/Axes using the existing Matplotlib method.
plt.show()                                      # Display the plot
